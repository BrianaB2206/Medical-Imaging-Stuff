# %%
import numpy as np
import scipy
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import os

# %%
#print(os.listdir('.')) # afisare continutului folderului curent

#path = os.getcwd() 
#print(path)
#print(os.listdir(r'C:\Users\brian\OneDrive\Desktop\Lab2_MI'))
#path = r'C:\Users\brian\OneDrive\Desktop\Lab2_MI'
img = mpimg.imread('2.png')
print('img is of: ', type(img))
print('shape/dimensions of the img variable are: ', img.shape)
plt.imshow(img)
plt.title('image \'CThead.tif\'') 

#matplotlib.pyplot.imshow(img, cmap = 'gray')
# Out:
# img is of:  <class 'numpy.ndarray'>
# shape/dimensions of the img variable are:  (227, 352, 4)
# Text(0.5, 1.0, "image 'CThead.tif'")

# %%
plt.title('image \'2.png\'')
plt.imshow(img, cmap = 'gray')

# %%
from PIL import Image
img1 = Image.open('2.png', 'r')
print('the size of the variable is: ', img1.size, 'and of type ', type(img1))
# Out:
# the size of the variable is:  (352, 227) and of type  <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
img2 = np.asarray(img1)
plt.imshow(img2, cmap = 'gray')

# %%
img3 = img1.rotate(45, translate = None)
plt.imshow(img3, cmap = 'gray')

# %%
plt.figure()
plt.subplot(1,2,1); plt.imshow(img2, cmap = 'gray'); plt.title('original')
plt.subplot(1,2,2); plt.imshow(np.asarray(img3), cmap = 'gray'); plt.title('rotit')
# Out:
# Text(0.5, 1.0, 'rotit')

# %%
img4 = img1.rotate(0,translate=(100,0))
matplotlib.pyplot.figure()
matplotlib.pyplot.subplot(1,2,1); matplotlib.pyplot.imshow(img2, cmap = 'gray'); matplotlib.pyplot.title('original')
matplotlib.pyplot.subplot(1,2,2); matplotlib.pyplot.imshow(np.asarray(img4), cmap = 'gray'); matplotlib.pyplot.title('translatat cu 10 pixeli la dreapta')
# Out:
# Text(0.5, 1.0, 'translatat cu 10 pixeli la dreapta')

# %%
img5 = img1.rotate(90, translate = None)

l = 0.1*img2.shape[0]
img6 = img1.rotate(0, translate = (c,0))
l = 0.1*img2.shape[0]
matplotlib.pyplot.figure()
matplotlib.pyplot.subplot(1,4,1); matplotlib.pyplot.imshow(img5, cmap = 'gray'); matplotlib.pyplot.title('rotated 90')
matplotlib.pyplot.subplot(1,4,2); matplotlib.pyplot.imshow(np.asarray(img6), cmap = 'gray'); matplotlib.pyplot.title('translated to the left')
matplotlib.pyplot.subplot(1,4,3); matplotlib.pyplot.imshow(np.asarray(img5), cmap = 'gray'); matplotlib.pyplot.title('translated down')
matplotlib.pyplot.subplot(1,4,4); matplotlib.pyplot.imshow(np.asarray(img1), cmap = 'gray'); matplotlib.pyplot.title('original')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 4>()
#       1 img5 = img1.rotate(90, translate = None)
#       3 l = 0.1*img2.shape[0]
# ----> 4 img6 = img1.rotate(0, translate = (c,0))
#       5 l = 0.1*img2.shape[0]
#       6 matplotlib.pyplot.figure()
#
# NameError: name 'c' is not defined

# %%
path = r'D:\Imagistica Medicala\Corina\Laborator_2'
img = matplotlib.pyplot.imread('prosthesis.bmp')
matplotlib.pyplot.figure()
matplotlib.pyplot.imshow(img, cmap = 'gray')
print(img[100,100], '*')
# Out:
# 202 *
